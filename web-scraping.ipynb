# %%
from bs4 import BeautifulSoup
import requests, lxml, re, json
import pandas as pd
from datetime import datetime

# %%
headers = {
    "user-agent":
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"
}

# %%
params = {
    "id": "com.halfbrick.jetpackjoyride",  # app name
    "gl": "US"                  # country
}

# %%
html = requests.get("https://play.google.com/store/apps/details", params=params, headers=headers, timeout=10).text

# %%
soup = BeautifulSoup(html, "lxml")

# %%
app_data = []

# %%
basic_app_info = json.loads(re.findall(r"<script nonce=\".*\" type=\"application/ld\+json\">(.*?)</script>",
                                       str(soup.select("script")[12]), re.DOTALL)[0])

# %%
app_name = basic_app_info["name"]
app_type = basic_app_info["@type"]
app_url = basic_app_info["url"]
app_description = basic_app_info["description"].replace("\n", "")  # replace new line character with nothing
app_category = basic_app_info["applicationCategory"]
app_operating_system = basic_app_info["operatingSystem"]
app_main_thumbnail = basic_app_info["image"]

app_content_rating = basic_app_info["contentRating"]
app_rating = round(float(basic_app_info["aggregateRating"]["ratingValue"]), 1)  # 4.287856 -> 4.3
app_reviews = basic_app_info["aggregateRating"]["ratingCount"]

app_author = basic_app_info["author"]["name"]
app_author_url = basic_app_info["author"]["url"]

# %%
app_images_data = re.findall(r",\[\d{3,4},\d{3,4}\],.*?(https.*?)\"", str(soup.select("script")))

# %%
app_images = [item for item in app_images_data if app_images_data.count(item) == 1]

# %%
app_images_data = re.findall(r",\[\d{3,4},\d{3,4}\],.*?(https.*?)\"", str(soup.select("script")))

app_images_not_filtered = [item for item in app_images_data]
app_images_filtered = [item for item in app_images_data if app_images_data.count(item) == 1]

print(len(app_images_not_filtered))
print(app_images_not_filtered)

print(len(app_images_filtered))
print(app_images_filtered)

'''
71
['https://play-lh.googleusercontent.com/dcv6Z-pr3MsSvxYh_UiwvJem8fktDUsvvkPREnPaHYienbhT31bZ2nUqHqGpM1jdal8', 'https://play-lh.googleusercontent.com/SVYZCU-xg-nvaBeJ-rz6rHSSDp20AK-5AQPfYwI38nV8hPzFHEqIgFpc3LET-Dmu-Q', 'https://play-lh.googleusercontent.com/Nne-dalTl8DJ9iius5oOLmFe-4DnvZocgf92l8LTV0ldr9JVQ2BgeW_Bbjb5nkVngrQ', 'https://play-lh.googleusercontent.com/yIqljB_Jph_T_ITmVFTpmDV0LKXVHWmsyLOVyEuSjL2794nAhTBaoeZDpTZZLahyRsE', 'https://play-lh.googleusercontent.com/5HdGRlNsBvHTNLo-vIsmRLR8Tr9degRfFtungX59APFaz8OwxTnR_gnHOkHfAjhLse7e', 'https://play-lh.googleusercontent.com/bPhRpYiSMGKwO9jkjJk1raR7cJjMgPcUFeHyTg_I8rM7_6GYIO9bQm6xRcS4Q2qr6mRx', 'https://play-lh.googleusercontent.com/7DOCBRsIE5KncQ0AzSA9nSnnBh0u0u804NAgux992BhJllLKGNXkMbVFWH5pwRwHUg', 'https://play-lh.googleusercontent.com/PCaFxQba_CvC2pi2N9Wuu814srQOUmrW42mh-ZPCbk_xSDw3ubBX7vOQeY6qh3Id3YE', 'https://play-lh.googleusercontent.com/fQ
leusercontent.com/SI2XoFyY35xzlMz3cZdTH7SSxMDfJTJjKNtbso33YIyYknmxJnBLrfLPJ131gz3O259sB9gP9dcmSvRNFw', 'https://play-lh.googleusercontent.com/SI2XoFyY35xzlMz3cZdTH7SSxMDfJTJjKNtbso33YIyYknmxJnBLrfLPJ131gz3O259sB9gP9dcmSvRNFw', 'https://play-lh.googleusercontent.com/pzvdI66OFjncahvxJN714Tu5pHUJ_nJK--vg0tv5cpgaGNvjfwsxC-SKxoQh9_n_wEcCdSQF9FeuZeI', 'https://play-lh.googleusercontent.com/EbEX3AN4FC4pu3lsElAHCiksluOVU8OgkgtWC43-wmm_aHVq2D65FmEM97bPexilUAvlAY5_4ARH8Tb3RxQ', 'https://play-lh.googleusercontent.com/_re6mcALPaqotePA0WkgYeOQ6TighHRUS62FRmREPEhyZPdGM3QmRjcSpiMt6Pz1O-WZyvEIy4mtGHj9zw', 'https://play-lh.googleusercontent.com/_re6mcALPaqotePA0WkgYeOQ6TighHRUS62FRmREPEhyZPdGM3QmRjcSpiMt6Pz1O-WZyvEIy4mtGHj9zw', 'https://play-lh.googleusercontent.com/z6aS2wnyp16KA9CFEep7HvZd2DmwRfoR9NWm9oHWRw-tuXLE_CPbnb1OL39-a456EgA', 'https://play-lh.googleusercontent.com/z6aS2wnyp16KA9CFEep7HvZd2DmwRfoR9NWm9oHWRw-tuXLE_CPbnb1OL39-a456EgA', 'https://play-lh.googleusercontent.com/z6aS2wnyp16KA9CFEep7HvZd2DmwRfoR9NWm9oHWRw-tuXLE_CPbnb1OL39-a456EgA', 'https://play-lh.googleusercontent.com/kMnXlmzr3b8Tbzs_xDy ...

# %%
app_user_comments = []

# %%
app_user_reviews_data = re.findall(r"(\[\"gp.*?);</script>",
                                   str(soup.select("script")), re.DOTALL)

# %%
for review in app_user_reviews_data:
    # https://regex101.com/r/M24tiM/1
    user_name = re.findall(r"\"gp:.*?\",\s?\[\"(.*?)\",", str(review))
    
    # https://regex101.com/r/TGgR45/1
    user_avatar = [avatar.replace('"', "") for avatar in re.findall(r"\"gp:.*?\"(https.*?\")", str(review))]

    # replace single/double quotes at the start/end of a string
    # https://regex101.com/r/iHPOrI/1
    user_comment = [comment.replace('"', "").replace("'", "") for comment in
                    re.findall(r"gp:.*?https:.*?]]],\s?\d+?,.*?,\s?(.*?),\s?\[\d+,", str(review))]

    # comment utc timestamp
    # use datetime.utcfromtimestamp(int(date)).date() to have only a date: 2022-01-09
    user_comment_date = [str(datetime.utcfromtimestamp(int(date))) for date in re.findall(r"\[(\d+),", str(review))]

    # https://regex101.com/r/GrbH9A/1
    user_comment_id = [ids.replace('"', "") for ids in re.findall(r"\[\"(gp.*?),", str(review))]
    
    # https://regex101.com/r/jRaaQg/1
    user_comment_likes = re.findall(r",?\d+\],?(\d+),?", str(review))
    
    # https://regex101.com/r/Z7vFqa/1
    user_comment_app_rating = re.findall(r"\"gp.*?https.*?\],(.*?)?,", str(review))

# %%
for name, avatar, comment, date, comment_id, likes, user_app_rating in zip(user_name,
                                                                           user_avatar,
                                                                           user_comment,
                                                                           user_comment_date,
                                                                           user_comment_id,
                                                                           user_comment_likes,
                                                                           user_comment_app_rating):
                                                                           app_user_comments.append({
    "user_name": name,
    "user_avatar": avatar,
    "comment": comment,
    "user_app_rating": user_app_rating,
    "user__comment_likes": likes,
    "user_comment_published_at": date,
    "user_comment_id": comment_id
})

app_data.append({
    "app_name": app_name,
    "app_type": app_type,
    "app_url": app_url,
    "app_main_thumbnail": app_main_thumbnail,
    "app_description": app_description,
    "app_content_rating": app_content_rating,
    "app_category": app_category,
    "app_operating_system": app_operating_system,
    "app_rating": app_rating,
    "app_reviews": app_reviews,
    "app_author": app_author,
    "app_author_url": app_author_url,
    "app_screenshots": app_images
})

# %%
def scrape_google_store_app():
    html = requests.get("https://play.google.com/store/apps/details", params=params, headers=headers, timeout=10).text
    soup = BeautifulSoup(html, "lxml")

    # where all app data will be stored
    app_data = []

    # <script> position is not changing that's why [12] index being selected. Other <script> tags position are changing.
    # [12] index is a basic app information
    # https://regex101.com/r/DrK0ih/1
    basic_app_info = json.loads(re.findall(r"<script nonce=\".*\" type=\"application/ld\+json\">(.*?)</script>",
                                           str(soup.select("script")[12]), re.DOTALL)[0])

    app_name = basic_app_info["name"]
    app_type = basic_app_info["@type"]
    app_url = basic_app_info["url"]
    app_description = basic_app_info["description"].replace("\n", "")  # replace new line character to nothing
    app_category = basic_app_info["applicationCategory"]
    app_operating_system = basic_app_info["operatingSystem"]
    app_main_thumbnail = basic_app_info["image"]

    app_content_rating = basic_app_info["contentRating"]
    app_rating = round(float(basic_app_info["aggregateRating"]["ratingValue"]), 1)  # 4.287856 -> 4.3
    app_reviews = basic_app_info["aggregateRating"]["ratingCount"]

    app_author = basic_app_info["author"]["name"]
    app_author_url = basic_app_info["author"]["url"]

    # https://regex101.com/r/VX8E7U/1
    app_images_data = re.findall(r",\[\d{3,4},\d{3,4}\],.*?(https.*?)\"", str(soup.select("script")))
    # delete duplicates from app_images_data
    app_images = [item for item in app_images_data if app_images_data.count(item) == 1]

    # User comments
    app_user_comments = []

    # https://regex101.com/r/SrP5DS/1
    app_user_reviews_data = re.findall(r"(\[\"gp.*?);</script>",
                                       str(soup.select("script")), re.DOTALL)

    for review in app_user_reviews_data:
        # https://regex101.com/r/M24tiM/1
        user_name = re.findall(r"\"gp:.*?\",\s?\[\"(.*?)\",", str(review))
        # https://regex101.com/r/TGgR45/1
        user_avatar = [avatar.replace('"', "") for avatar in re.findall(r"\"gp:.*?\"(https.*?\")", str(review))]

        # replace single/double quotes at the start/end of a string
        # https://regex101.com/r/iHPOrI/1
        user_comments = [comment.replace('"', "").replace("'", "") for comment in
                        re.findall(r"gp:.*?https:.*?]]],\s?\d+?,.*?,\s?(.*?),\s?\[\d+,", str(review))]

        # comment utc timestamp
        # use datetime.utcfromtimestamp(int(date)).date() to have only a date
        user_comment_date = [str(datetime.utcfromtimestamp(int(date))) for date in re.findall(r"\[(\d+),", str(review))]

        # https://regex101.com/r/GrbH9A/1
        user_comment_id = [ids.replace('"', "") for ids in re.findall(r"\[\"(gp.*?),", str(review))]
        # https://regex101.com/r/jRaaQg/1
        user_comment_likes = re.findall(r",?\d+\],?(\d+),?", str(review))
        # https://regex101.com/r/Z7vFqa/1
        user_comment_app_rating = re.findall(r"\"gp.*?https.*?\],(.*?)?,", str(review))

        for name, avatar, comment, date, comment_id, likes, user_app_rating in zip(user_name,
                                                                                   user_avatar,
                                                                                   user_comments,
                                                                                   user_comment_date,
                                                                                   user_comment_id,
                                                                                   user_comment_likes,
                                                                                   user_comment_app_rating):
            app_user_comments.append({
                "user_name": name,
                "user_avatar": avatar,
                "comment": comment,
                "user_app_rating": user_app_rating,
                "user__comment_likes": likes,
                "user_comment_published_at": date,
                "user_comment_id": comment_id
            })

        app_data.append({
            "app_name": app_name,
            "app_type": app_type,
            "app_url": app_url,
            "app_main_thumbnail": app_main_thumbnail,
            "app_description": app_description,
            "app_content_rating": app_content_rating,
            "app_category": app_category,
            "app_operating_system": app_operating_system,
            "app_rating": app_rating,
            "app_reviews": app_reviews,
            "app_author": app_author,
            "app_author_url": app_author_url,
            "app_screenshots": app_images
        })

        return {"app_data": app_data, "app_user_comments": app_user_comments}


print(json.dumps(scrape_google_store_app(), indent=2))
# Out:
# {
#   "app_data": [
#     {
#       "app_name": "Jetpack Joyride",
#       "app_type": "SoftwareApplication",
#       "app_url": "https://play.google.com/store/apps/details/Jetpack_Joyride?id=com.halfbrick.jetpackjoyride&hl=en_US&gl=US",
#       "app_main_thumbnail": "https://play-lh.googleusercontent.com/hnT4EXfDEIgqWkVAhXLizRzG4tcrrrBh8qNcJoj6-ndwQCHulZC9xIzREapQp8hqeQ",
#       "app_description": "Bullet-powered jetpacks! Giant mechanical dragons! Birds that shoot money!From the makers of Fruit Ninja comes this insane, high flying endless runner that will keep you on the edge of your seat!It's time to join Barry Steakfries and equip cool jetpacks, suit up in stylish costumes and ride crazy vehicles in his endless running quest to beat the scientists to the end of the lab.Join over 750 million players and download Jetpack Joyride on the Google Play Store!Download FREE now to start a new game and escape the lab!FEATURES:\u26a1Fly cool jetpacks through the lab\u26a1Surf the wave-rider in all its glory\u26a1Complete daring missions to boost your rank\u26a1Customise your look with ridiculous outfits\u26a1Dodge lasers, zappers, and guided missiles\u26a1Collect coins and make millions of dollars\u26a1Storm the lab in giant mechs and crazy vehicles\u26a1Equip high-tech gadgets and power-ups\u26a1Earn achievements and battle it out against friends\u26a1Test your reflexes with simple one-touch controls\u26a1New free game modes in special events***This game contains optional in-app purchases. You can disable this feature in the settings menu of your device.View our privacy policy at http://halfbrick.com/ppView our terms of service at http://halfbrick.com/tos",
#       "app_content_rating": "Everyone 10+",
#       "app_category": "GAME_ARCADE",
#       "app_operating_system": "ANDROID",
#       "app_rating": 4.6,
#       "app_reviews": "4957030",
#       "app_author": "Halfbrick Studios",
#       "app_author_url": "http://www.halfbrick.com/our-games/jetpack-joyride/",
#       "app_screenshots": [
#         "https://play-lh.googleusercontent.com/FX3WQx1CFAvZ2hNoKaTp2BNa_3uIE7rTfo0vBiXa6wCeAwLn9RgiOz14SX7q4iXuyR4",
#         "https://play-lh.googleusercontent.com/RY8ZPQb5Upk_Rdy5Q2qX78BAX7CNRz5F086A6fDFRGmbKbbGk-v6Nt12_9iA3BQJiA",
#         "https://play-lh.googleusercontent.com/W1mGeSgsFUFhBTYAjcctXER2RdtpZQeSjugm0TXYhdFQXuC_IxjEGP1WLa2qTRdfVKM",
#         "https://play-lh.googleusercontent.com/KWjfcscAteIDSPn0KSfpZoJSFcKPPkUauRLYqvE35aIaQ9skrfD8UQeSQDRqt3YWlUBm",
#         "https://play-lh.googleusercontent.com/CEi_ekivSd7JgOy7mswt3OETDdABcowm7MCl5vRl2MmFs2ItZR_ujiKsuwEAFeljBC0",
#         "https://play-lh.googleusercontent.com/-6A8XnU-JjUvWTmJi-NHo93RgkK3XVqpNcSt6-xk_GQRapZLY88aylulkVS8TzKHvBw3",
#         "https://play-lh.googleusercontent.com/hnT4EXfDEIgqWkVAhXLizRzG4tcrrrBh8qNcJoj6-ndwQCHulZC9xIzREapQp8hqeQ"
#       ]
#     }
#   ],
#   "app_user_comments": [
#     {
#       "user_name": "DROID",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GjIT5ybmXHKRueTkgh3x-Asrgkd2_JCK4_VYMdLCg",
#       "comment": "I love the game itself, its actually really fun! But the one reason why it doesnt get my five stars is because Im starting to wonder what this game has turned into. It used to just be a fun game where you can fly and and can buy new jetpacks n stuff. But now, its littered with ads, so many in app purchases that its hard to count, and some of the events and new mechanics are kind of boring, hard to understand (for some people), and just generally kind of stupid. Please make this better.",
#       "user_app_rating": "4",
#       "user__comment_likes": "37",
#       "user_comment_published_at": "2022-05-16 23:21:18",
#       "user_comment_id": "gp:AOqpTOHbcYH6JnQ7wC800FlQGsd_PhbmjTYSraew7Jyg4om-UbiN2-GuFBIppOxVNaBBIOu6xeGVunTsSiVgIZs"
#     },
#     {
#       "user_name": "PhantomRaptor1",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GhQpkD8AVLb1VI2ujhYaRCfk8eDIqoyox9mNpc6",
#       "comment": "Still a great game even after over a decade. My only complaint is how certain items are locked until you pay for them, such as the 3rd item slot and certain vehicles, but it doesnt detract from the gameplay at all and ads for in-app purchases are rare enough that theyre not bothersome. Updates are constant and keep the game fresh, as well. Still a classic mobile game, and Im excited to see what your team will release next!",
#       "user_app_rating": "4",
#       "user__comment_likes": "485",
#       "user_comment_published_at": "2022-03-18 22:41:50",
#       "user_comment_id": "gp:AOqpTOGM2Apvelih7MXO6sYldLb0PU9aE2Iycm_rH4MviIglo_7ISLgiUO_X5u7xQTtC17LbPHJiGRR2osYW2sQ"
#     },
#     {
#       "user_name": "Jesse Osborne",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GjNwRu-hIkY4bj_gGcpmZkzuHNN1CfpcyFgtR-ZQA",
#       "comment": "This game is amazing! like Seriously! This game vey addicting Heck, im even playing this on computer, and its still addicting. BUT the Only thing that annoys me is advertisements. Now i know that ads are supposed to be in free games to get money for the developer/developers, But its just annoying that most of the time when you press next, most of the time, it gives you an ad. another thing is about the bugs. Its not that many but this is a well game but there can still be some. Thank you. :)",
#       "user_app_rating": "4",
#       "user__comment_likes": "340",
#       "user_comment_published_at": "2022-03-05 22:01:47",
#       "user_comment_id": "gp:AOqpTOGtU7Ezgc0L6j3FqKnUys75B4J1qOZ2IttDAnMA-4cz55KSEhOvduKX_W44QC-ZFgeRJVl9KrFJ5Su9VX8"
#     },
#     {
#       "user_name": "Dominic Platt",
#       "user_avatar": "https://play-lh.googleusercontent.com/a/AATXAJwpI4lhe9ccCRNylvP03f8BBcm7bhHe9epuZARs\\u003dmo",
#       "comment": "It just updated to new version 1.63.1 and is still saying It needs to be updated. A bit frustrating now I cant play the game. I have liked playing the game, a little frustrating seeing a whole bunch of ads and the game stuttering while connected to the internet, and having to pay for certain vehicles or the third add on. Hopefully I can get it working again",
#       "user_app_rating": "3",
#       "user__comment_likes": "127",
#       "user_comment_published_at": "2022-04-06 08:55:14",
#       "user_comment_id": "gp:AOqpTOGNwYefsy9v7Pyywk6vqNRd5-gCwCHZ0-VWfeHYvS3pgPxyx2thHLxw7apDv5zgbe6Wzvpr6ojmivXLRJk"
#     },
#     {
#       "user_name": "The Atlas V",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14Ghee7t-WJzUxc5z-lL5uRCAFLoQDonjQ1dchXh7IQ",
#       "comment": "I love this game. The music is awesome, the purchases arent very scammy (although I do miss the third gadget slot), you dont get the feeling that you have to spend money to get anywhere because all the purchases either are just for looks, or just help to speed up progress. This is even an OG game from childhood that only charges a dollar to remove all ads permanently, unlike SOME companies that charge a monthly 7.99 subscription to remove ads from their games...",
#       "user_app_rating": "5",
#       "user__comment_likes": "70",
#       "user_comment_published_at": "2022-04-07 06:46:16",
#       "user_comment_id": "gp:AOqpTOGLFN0hZ3CgvaeYelecD2p0jBPHL_E3DV0IU1EnEr7yovpz95FASrOeolob7a_UsmKtyat4_KDKdKTNXBg"
#     },
#     {
#       "user_name": "Jasmine S.",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14Ghxs0-sCo1q5kUzo4hF3uTYV-AngUSf4Ag8LedDcA",
#       "comment": "This games amazing. Ive played this ever since I was little, and still, its going to be apart of me forever. I really have no complaints though. Only here to say good things. The outfits you get in the game is incredible, you can make him look silly, cute, scary, or anything youd like. This game is not a bowling game too. In this game, you pretty much get high scores and coins to get outfits or a record. In the music videos they make, theres a story along with it.",
#       "user_app_rating": "5",
#       "user__comment_likes": "9",
#       "user_comment_published_at": "2022-03-16 12:19:13",
#       "user_comment_id": "gp:AOqpTOH9nxnje2vS6pVyPUZAyokvrt8YlHXNh9NPoV8CNCFcHFjjAnZtVmrI84ujafp_gSyNy0RJh0QItT3YhxQ"
#     },
#     {
#       "user_name": "Paul Aragon",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgBI0aOaDH02pcJGqHASJT4_iwxTwXCad5DW7IOFA",
#       "comment": "It is a great game and I do understand that ads help fund the game to make it free for users. With that said, it is frustrating that after every run an ad plays. When youre in the zone and want to focus on the challenges, you get distracted. An ad after 3 runs wouldnt be so bad. Or the option of getting items after watching the ad. There is already the option in game where you can watch an ad and receive an item. I believe there is an option where you buy in game currency and ads disappear.",
#       "user_app_rating": "4",
#       "user__comment_likes": "393",
#       "user_comment_published_at": "2022-04-16 14:35:57",
#       "user_comment_id": "gp:AOqpTOELPyEjsdBdRbBppU8PAHK8TUyq8b--73Fh_Js52vHvv9_CLomsujfIuC3iq7trdZNVwJk5_jTK80tQi1I"
#     },
#     {
#       "user_name": "GamurSnek",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14Gi6PDVsPNDZ2a3KaFjUTbDvJvTMn6OucIS1K3eVHw",
#       "comment": "Always a great time as it used to be. Although, it does feel like its a bit ad heavy and overselling itself. Its cramoed with ads now and full of things you have to pay money to have. I couldve sworn the third gadget slot used to be free, but maybe I just remember wrong. Either way, still memorable and fun, and the humor in the descriptions of most items are fantastic",
#       "user_app_rating": "4",
#       "user__comment_likes": "107",
#       "user_comment_published_at": "2022-02-21 02:21:41",
#       "user_comment_id": "gp:AOqpTOHKE8uZKqW3Fzstj1qfXKxXHFoRhmrecI7l32h28RGnwnC7-WwdMVTMOH1WbeCuuNnJSEIkb7yfUQ3vw1Y"
#     },
#     {
#       "user_name": "Carson",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgbvTCWApZ6_UNDyaSldCAJsHz_YaaEkFBtVJVUxg",
#       "comment": "Great times. Not one bad experience with the game especially with the Ghostbusters event. I do have one complaint that doesnt really change the quality of the game but getting a fast amount of coins is rough. Anyway I have been playing since the beginning and recently got back into it. Great game!",
#       "user_app_rating": "5",
#       "user__comment_likes": "66",
#       "user_comment_published_at": "2021-12-07 01:31:26",
#       "user_comment_id": "gp:AOqpTOGqjqCOe1fpPEK4kPH8zlj3tMCF4PowpAiqQDUKhbcR913ucKBXkyRF2f6_ZFH9c7Dn5COF2caTYy-_U9Q"
#     },
#     {
#       "user_name": "Superb Supremo",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GhMD8DJsCEkKnb7vgf2OjrTr4Gpd6fzERxr-aKT",
#       "comment": "As this game changed for over a decade, I still remember this game even in the pandemic. The game is very simple, hold youre finger to make your player go up, and release the finger to stop it, see? simple right? As there are events in this game to make things fresh as possible, its really one of those games that you can play during a road trip. You can purchase some things off of it, but thats just an option if you are willing to get the 2x coins and the third gadget slot. Overall its good.",
#       "user_app_rating": "3",
#       "user__comment_likes": "1",
#       "user_comment_published_at": "2021-12-07 13:00:43",
#       "user_comment_id": "gp:AOqpTOH5WkGRq6YQNot2Yg12rdnpVuRMpukI9JWX571S--Q-aeOIibGZt0GFaQiCJIXfI3kYTDYBs0154C4wm70"
#     },
#     {
#       "user_name": "Benjamin Sexton",
#       "user_avatar": "https://play-lh.googleusercontent.com/a/AATXAJyYigtq2kyi4vxH0UDefmktS4KAq7TKg4C9gs5S\\u003dmo",
#       "comment": "Timeless game. The gameplay is enjoyable, there are personal goals you can set such as reaching a level, unlocking certain jetpacks/costumes, or getting higher scores. These keep the game addictive and give a feeling of progress. Although the game doesnt really have any new \\content\\ added to it outside of cosmetic stuff, I do think its well maintained. My only complaint is that my coin doubler that I purchased years ago isnt active anymore and I cant seem to get it back.",
#       "user_app_rating": "5",
#       "user__comment_likes": "2",
#       "user_comment_published_at": "2022-03-22 22:56:53",
#       "user_comment_id": "gp:AOqpTOFW7MyaqEVEPQTcGROXKx0IVOQOq835OnP66BTBIrJb0uQNaWhhTUlAbhRQXYhTjBle9EfPiaOyZq0O4qU"
#     },
#     {
#       "user_name": "AwesomeGuy3317 !",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GiaPbfJiXEfar9DZwZ5tPzJ8ARPzvp6AOmvkti5Iw",
#       "comment": "Dont get me wrong, I love this game. The thing that really bothers me is that after an ad pops up, everything in the game gets messed up. The textures are all switched up, everything looks really bad. The dude you play as is just a block of textures that include the \\A\\ from \\S.A.M.\\ and some textures from lasers. making the game unplayable. Please fix this",
#       "user_app_rating": "2",
#       "user__comment_likes": "71",
#       "user_comment_published_at": "2022-03-23 04:45:20",
#       "user_comment_id": "gp:AOqpTOGbHX_GhCCw0H53Y5pwKBXV4xYUOrz72XMLbD3SknwBqt9_jueOwUnLfoGSVyRBpgKevc55NJnwNZJHEP0"
#     },
#     {
#       "user_name": "E Larson",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgH1eZFEuow3Bd5P8zDB14aHuREEns1IsYPwaX_tw",
#       "comment": "I like the game, I think it has a glitch though. It seemed to erase my progress. I signed in on Google play, that was an easy fix. But then I went into the gadgets menu, and I couldnt access the gadgets Id bought. It was like the time before Id bought them when the higher levels are dark and you cant tap on them, but it still showed that I own them. I bought some more from level 1 which I hadnt bought yet, hoping it would unlock the next level, and it didnt. Otherwise, no trouble.",
#       "user_app_rating": "4",
#       "user__comment_likes": "2",
#       "user_comment_published_at": "2021-12-19 11:25:23",
#       "user_comment_id": "gp:AOqpTOFKdc9679q1ieRsV6uVgHbEAj0_BGcrv086YjPYZZzu74WI6bQfQ2lpQbU-v85EJcYkpOtGwsW77NjGSLM"
#     },
#     {
#       "user_name": "Heather Brown",
#       "user_avatar": "https://play-lh.googleusercontent.com/a/AATXAJxNz6uTe1xPEVfxoTvsf1WL5bYfH1bW4x7SNDbG\\u003dmo",
#       "comment": "Honestly, I have been playing this game for many many years, and used to absolutely love it. Recently, it has gone down hill. Since getting more popular, the adds have gotten a bit rediculous, and also more and more missions are starting to glitch. Ex: One mission will be \\Fly over 18 zappers in one game\\, and it wont register or be marked as complete for 2-3 games, regardless to how many you fly over (plus many other issues with other missions).",
#       "user_app_rating": "3",
#       "user__comment_likes": "6",
#       "user_comment_published_at": "2018-12-28 18:28:45",
#       "user_comment_id": "gp:AOqpTOHTMqME43P7_KmHv8HKFUeZE62oUx8LSRLTLU9bfk-kKYhjCB_kDvQMxL3SSmWcuaryHi8nHGsgys_rOTg"
#     },
#     {
#       "user_name": "Logan Dugan",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgLtgHCb7BEs9BzldRdB7xysb_LT_HMkHDZPHkEeg",
#       "comment": "Its a classic and wonderful game that I believe everyone, with access, should play, if they havent already. Ads are always a given when it comes to free mobile games. Though, I dont like that fact that you have the choice to watch an ad to double your coins, or similar small boosts, and after refusing or skipping, it plays an ad reguardless. This is the only downside, in my opinion, otherwise great game.",
#       "user_app_rating": "4",
#       "user__comment_likes": "108",
#       "user_comment_published_at": "2019-02-10 03:38:20",
#       "user_comment_id": "gp:AOqpTOG6OUyObmcwM1EpH_9xkFauOxiJeeokSnaVGJcgaliOJGIYNw7UV3FPtqPXQaiMECkoOoVS1GfZpWLMYy8"
#     },
#     {
#       "user_name": "Chao",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GjdBCE_2QUF4zc386Q_mWyvwmv4uUGWa2kUdhAM",
#       "comment": "A very enjoyable classic with tons of replayability. However, after playing for some time, the latest update as of this review has made playing the game impossible due to a softlock on the loading screen on boot. Further, it seems this game has been plagued with an immense amount of lag during gameplay, something which was not the case when I played years ago. Until these issues get resolved, I will keep my review at 1 star.",
#       "user_app_rating": "1",
#       "user__comment_likes": "4",
#       "user_comment_published_at": "2019-01-08 16:01:58",
#       "user_comment_id": "gp:AOqpTOGfjUFBs0L8WrmEnIeLIAEI2HbTUJ0XM1O8j0rPY4n41gTEZeOMLXYqpAvtGQdDtCVljIsZPNx5mkhzBAc"
#     },
#     {
#       "user_name": "Gabriel Maisonet",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GiWzEnOHbQzJ29oPv0BoJoMA2vNM9boCxhi6RrB",
#       "comment": "Great mindless game. Love the art. The pacing of each run is well crafted, with how gradually it speeds you up. Horrible in game ads though. The game opened fine the first time. I havent been able to open the app since; it gets stuck at the beginning of the loading bar (it doesnt freeze the app, just stops loading the bar). Tried uninstalling \\u0026 reinstalling, turning phone off, etc, no fix",
#       "user_app_rating": "2",
#       "user__comment_likes": "2",
#       "user_comment_published_at": "2019-09-20 02:56:26",
#       "user_comment_id": "gp:AOqpTOFDrqYcJaAswu-fL1XLVCYmBFZqJqcAJ-WfV7gurq3XicTwYf1I-lidGqjq3XmJdrbGns502oUk_d_SZ5A"
#     },
#     {
#       "user_name": "Samuel Duncan",
#       "user_avatar": "https://play-lh.googleusercontent.com/a/AATXAJzZRCrjB6G3S3ilWHYpw6Alg65RcGqJhoxtilAi\\u003dmo",
#       "comment": "Ive played it in the past and enjoyed it each time. But whatever changes have been made over the years are causing problems. Namely, I cant build a streak with the S.A.M. now. If I dont get all three tokens within a certain amount of time, it not only resets the tokens to zero, but puts me back on day one of five. Kinda hard to build up to the next reward when the game wont let you.",
#       "user_app_rating": "2",
#       "user__comment_likes": "1",
#       "user_comment_published_at": "2019-09-23 01:19:54",
#       "user_comment_id": "gp:AOqpTOGOiGmCZUgrDRlV1gyK17hgnkgPCZTmnnQVaeXN-S7kPThFR2Hms2xUVtqfrzEE84UlrzfrpR9eh8tSTLo"
#     },
#     {
#       "user_name": "Blaizerman777",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgO_Vq_qNEmXTp008NMVc8q1Wyt50tcrduJXI1pew",
#       "comment": "Definitely love this game through and through, and Ive gotten back into it recently having played it as a kid. Ive been making a lot of progress but recently its started crashing every time I try to open the app. I get like 3 seconds of loading screen and then it closes. Idk what happened but its kinda disheartening and Im afraid to uninstall and lose all my progress when I reinstall to get it to work again. Keep up the good work on this timeless masterpiece tho",
#       "user_app_rating": "4",
#       "user__comment_likes": "327",
#       "user_comment_published_at": "2020-08-09 13:54:43",
#       "user_comment_id": "gp:AOqpTOGHN-levTYjmsPV-QAafEtdsibl2LbQjVEk4pRE5YBMU7fZanHd126EOkN4MvU4b2EfY98S_BrJ546yB10"
#     },
#     {
#       "user_name": "Michael Morris",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GjswtRcDJpsnI2Lp1rm4Cnne2MigHkPqRs7H4Nb",
#       "comment": "Ive been playing this game on and off for 8 years, and its always fun to come back to. The addition of the power ups, and watching ads for more.gold or to skip missions is very welcome. Onky issue is when doing a cover a distance on foot mission comes up, it wont register the first time, and you have to play again to get it to count",
#       "user_app_rating": "4",
#       "user__comment_likes": "156",
#       "user_comment_published_at": "2020-08-11 15:37:51",
#       "user_comment_id": "gp:AOqpTOHnSQf4BGNVbc8TP6hL4TnfZxlQQiGTMxWcAjHu2pshwB6V3x7jOmvMeLwBGjwRsKrkk3tN1FuBizdZsSg"
#     },
#     {
#       "user_name": "michael nixon",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GjxBmut1r95XXkSpc155ZJgX_8pc6GgRkDF7KkY",
#       "comment": "My sister got me to play this game years ago and got it again to play with my kids. Lol. Passing on the fun. A silly, enjoyable game that is still fun play. Though, I have to say I dont recall all the adds. Excessive at times and takes away from an otherwise good game. Sucks that so many games seem to be intentionally annoying to get you to spend the money just to get rid of the adds. Sure, only a couple of dollars, but if they just minimized the adds, I might actually pay attention to them instead of getting frustrated and just counting the seconds to be able to skip them. Just saying.",
#       "user_app_rating": "4",
#       "user__comment_likes": "251",
#       "user_comment_published_at": "2020-07-11 16:26:01",
#       "user_comment_id": "gp:AOqpTOEstHKW_asINUHcSa36IOvIM9wxGACzj2Ew-3NUEUtYAa1jxkUtzZK0aPtuk57HkE3McxkYrRw1zkceDTo"
#     },
#     {
#       "user_name": "Mark Wilcox",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgcBO41BnqarSpPoZUICNTLnq8cZo2tmdOpPliyBw",
#       "comment": "This game is simple and fun and I have enjoyed it for a long time. Its a simple dodge game were you see how far you can get past certain obstacles and try to challenge yourself and friends. My biggest grip is how much trouble the game save backup system is it can be rather finicky. It seems to work fine some days and then say \\cloud backup failed\\ the next. The constant addition of new content is great but, if we have to risk losing what we worked I cant give the game a full five stars. Hope that at some point in time they can get that resolved.",
#       "user_app_rating": "4",
#       "user__comment_likes": "424",
#       "user_comment_published_at": "2021-05-01 03:51:03",
#       "user_comment_id": "gp:AOqpTOFKheo06X5wUMTDCH3edCLLV2ls8FhCj20dSuHNat9kqFOUPekHNkq9WuPmXJ1Hwi4KN7QcEt99Y2agd6c"
#     },
#     {
#       "user_name": "Abi Griffin",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14Gg2_AMbuf47eMiqNl-jKfbb2pejW4sjXZRxAP2Tcw",
#       "comment": "The most recent update changed the menus, making the game feel weird and not as rewarding. This is especially due to the stars no longer actually showing and instead being a boring progress bar. It was really rewarding to watch all of the stars pop into place, but now its so dull and makes me less eager to complete missions. Please change it back. You fixed what wasnt broken.",
#       "user_app_rating": "2",
#       "user__comment_likes": "3",
#       "user_comment_published_at": "2021-05-04 15:56:27",
#       "user_comment_id": "gp:AOqpTOF-1PJTvl2KdQUMfEEhSWtOaR64uSra478yI2ppfUqHpviUNQ4t0-sdt2EPAfDkjXK09fDuj-6ciaJyLP8"
#     },
#     {
#       "user_name": "Evalyn Wilson",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GhrhASguQmsK36xhjX0-ENt45Clo7wsokR3_peJ",
#       "comment": "This game now works and I still have all my old purchases! Very happy to be able to play this game again. A few of my favorite things: the missions, the gadgets, and the amount of character and machine customization. I think the biggest area of improvement would be to get the events to consistently work - right now the Back to the Future event is a little wonky, with disappearing character/vehicles.",
#       "user_app_rating": "5",
#       "user__comment_likes": "413",
#       "user_comment_published_at": "2021-03-24 14:43:43",
#       "user_comment_id": "gp:AOqpTOGbfkJDGq02PFJeMxrtgzqqZcsJoQq1Y9nPfIw7_U1vffNmvWewfAfVQ4qjjLwgOAsh8Du8EspV4UFMOxg"
#     },
#     {
#       "user_name": "Nikolas Robinson",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgzR7sExkb0FDIdc6RTm_XCnz3gqLFEWXAY5zk43Q",
#       "comment": "I have never personally played the game, but my girlfriend plays it almost compulsively. I am basing this review on the Amazing Customer Service provided by the company. My girlfriend had been playing for months on a guest account on accident, without noticing, and she accidentally pressed Uninstall instead of Update when she was trying to update the game. All progress shed made was lost, and that could have easily been the end of it, but customer support went above and beyond to help.",
#       "user_app_rating": "5",
#       "user__comment_likes": "96",
#       "user_comment_published_at": "2021-03-25 12:18:49",
#       "user_comment_id": "gp:AOqpTOH2OZLOCQXKua7wisnG7XK3XwwZ9uA-y63cMLAm06an8S45CyZ4rvcIQY5TyR1uDvuxl-LabzC9yDwjSZE"
#     },
#     {
#       "user_name": "Welberz",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14Ggu1ugvFf9sef0u8SD_2tk0M1e0pdTEwOnY44dj7Q",
#       "comment": "Ive been playing this game for a while now, and back in like 2016? It was a super fun easy game for all ages, I dropped it for a while and got it back in 1018 no changes still super fun, dropped it again and by the time I found it again it was 2020, changed, its not much different but i find it a coincidence that when the update happened, only then was there slight lags, I have no problem with the game the lags are just a bit annoying.",
#       "user_app_rating": "4",
#       "user__comment_likes": "117",
#       "user_comment_published_at": "2021-07-26 00:13:43",
#       "user_comment_id": "gp:AOqpTOF1cYZFAWfVtI6M8WAKFYeXH5KwpZHnwMUcpNFFaFgAiVBDRzcWlK39v3cysc8WM2VAebFwQbMBeGuQIo8"
#     },
#     {
#       "user_name": "Jason Lowry",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgU-HPv2hadiUoFC2upwL2ax5CJkPOLJms-Hib87w",
#       "comment": "Great game, very addictive. I have been playing for years and love wasting time on it. If I could suggest an improvement however, it would be a vehicle shield that could be upgraded maybe as a future power-up. I feel that this could help players achieve longer runs in the vehicles and make an already fun game even more fun. Thank you for your time and once again, great game.",
#       "user_app_rating": "5",
#       "user__comment_likes": "25",
#       "user_comment_published_at": "2021-07-26 16:55:18",
#       "user_comment_id": "gp:AOqpTOFRX48F1RAScVIz0fQffalPCZ-XyZim2Qk4eSWSHsZTkpgo6bGuNeSdLq5lW6idzSw9-0qhqylirC6mllY"
#     },
#     {
#       "user_name": "Blue",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GiC-MRU2bzsKyfPQjO-zoYlhv0ss9KMIupCoH2B",
#       "comment": "This game is very addictive. However, i still needs a little polishing (despite it having been around for so long). The tokens will sometimes end up inside the zappers, making them impossible to get without dying. Also, this may just be my phone, bit the game usually freezes shortly every 5 seconds.",
#       "user_app_rating": "4",
#       "user__comment_likes": "45",
#       "user_comment_published_at": "2018-11-16 05:08:32",
#       "user_comment_id": "gp:AOqpTOGfUX44gZOjyHslwWTn_BzLx4nXQTEGnLhPqyVqpTumjYraowmuAWn2mySuKTd9jNOcvHPre0rbgNo744g"
#     },
#     {
#       "user_name": "Randumb Guy",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GhijVuW5yuDfv5bttoV_LcKZXhp3-IqfoJslQYbWA",
#       "comment": "I played this game as a kid, and then again a couple years ago. Played every day and eventually unlocked everything. I mean EVERYTHING except for some of the time-based rewards. Paid for double coins (of course). I had to delete it and when I tried to play again on my new phone recently, I found that nothing was saved, not even purchases. Not that it matters as laggy as the game is now. I have faith in halfbrick, but I am largely just disappointed. Seems like a step backwards.",
#       "user_app_rating": "2",
#       "user__comment_likes": "1",
#       "user_comment_published_at": "2020-08-22 05:42:04",
#       "user_comment_id": "gp:AOqpTOH4iYG4k_eekKJuxUH77tyVd0ggZC7TZiQ5dfdxPSqBEzpRtFbXRmwkbx76zhokdPrDuRB7BDk-HZWV01k"
#     },
#     {
#       "user_name": "Gibran Adnan",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GijHx0urXbyrlxRNMmvuGzJn2ncVHqv_395jolMxw",
#       "comment": "Great game. I remember playing this years ago and when I redownloaded I really enjoyed it. I have had it for about a month and now there is a problem thats making it really hard to play. Every other second the game freezes for a little under half a second and then continues and then freezes again, etc. I think this is a bug that will get patched and believe this is from the new update, but until a new update comes, dont download it because it is freezing far too often to make it fun to play.",
#       "user_app_rating": "3",
#       "user__comment_likes": "191",
#       "user_comment_published_at": "2020-08-19 17:22:25",
#       "user_comment_id": "gp:AOqpTOHXFn_u0P-lp_g1MD5rOr1z_jQ388l60Sa7JTNVVnCUJyP71p_ncglB_Cgmg5xK3CKIr8ZfSke6lwMdcHI"
#     },
#     {
#       "user_name": "Mikage Pambisito\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b\u2e3b",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GhiEwPkD_CLXVPzedsO4_4EoD58i3iQqVz5BIRaIA",
#       "comment": "This is one of the classic mobile games, deemed masterpiece by some, which makes sense being a very good game. But it feels old in 2021, it starts being very repetitive after some weeks to the point were I deleted it. It needs a way to make it fun without so much repetition, and Jetpack Joyride 2 sadly wasnt the answer to this issue.",
#       "user_app_rating": "4",
#       "user__comment_likes": "1",
#       "user_comment_published_at": "2019-06-13 10:43:13",
#       "user_comment_id": "gp:AOqpTOHFS2V0FsXZWYI969JjOVGlqst1PZr2kmI-uC9QmNQeXud3NEe8TBBn7j0qHuXsK9IdlqHQt992I9h3tCU"
#     },
#     {
#       "user_name": "A Google user",
#       "user_avatar": "https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g",
#       "comment": "i love this game. its simple, and in its simplicity its eligant. the problem is a glitch that has occured to my system multiple times. after a certian point of owning the game, the game will stutter every few frames everytime i start the game up. On top of that, it crashed my phone. its annoying and seems to have no cure. ive had this happen on my 3 past systems, as well as my current system. im dissappinted because of this, rendering this game unplayable by me. please fix this!",
#       "user_app_rating": "3",
#       "user__comment_likes": "1",
#       "user_comment_published_at": "2020-10-14 13:05:06",
#       "user_comment_id": "gp:AOqpTOHmrs3AaZJMAhebceB-z7ly9J9FVEPy7qmLNG54fnD9_v5z72quJzk28NKEzG99WKUupy5e7HNaWO5pH5g"
#     },
#     {
#       "user_name": "Buddy Fritz",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14Giw843rl9vx_yf6-B6cLRFuAkgR7AukSVPZFrRMWQ",
#       "comment": "There are too many adverts. Whenever I finish a round and after the timer runs out for the big blast, quick revive or S.A.M., it gives me an ad. And if I dont have a good connection to Wi-Fi or data, it makes me crash. In every other game I have ever played off of data/Wi-Fi, there were never ads that played, probably to avoid this problem.",
#       "user_app_rating": "3",
#       "user__comment_likes": "1",
#       "user_comment_published_at": "2020-10-14 15:40:25",
#       "user_comment_id": "gp:AOqpTOEefLZc1nceW33Rgfrt-80razTcnjj_MjQ_u3ubGg7w4_xAXXyIZrxTWQwsT1xpSTlYGT43ThOsCPTJ9Pk"
#     },
#     {
#       "user_name": "David",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgOLNSudgyC3cHEQU6FiFHs0ppYO7YmtS_q5yI4pw",
#       "comment": "One of the last few games that is actually playable with not too many ads spamming your screen. They are there but you have to specifically click in order to watch to revive. But when you click play again, after you lost if you dont want to revive thats okay because it doesnt spam you with 30 second ads like most new games. I like this game, it gets 5 stars as its the few last games where the developer actually xares about people enjoying it more instead of caring about making money.",
#       "user_app_rating": "5",
#       "user__comment_likes": "514",
#       "user_comment_published_at": "2019-01-15 04:37:15",
#       "user_comment_id": "gp:AOqpTOEGm_uz5iKyP_QGJKS2Agb33tPLMY_MmWhVizuIPn8V9exZIriA0JKW6gXmElN0CDnrTlGzqgp2WrNijrY"
#     },
#     {
#       "user_name": "Pumchi",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GiM3kH80KEXu3Yi8Z9j28RTFVFt7xzR2SrKAwjz",
#       "comment": "Ive been enjoying this game since elementary school. Its an amazing game! Ill continue to play it! I love the graphics, music, and I overall just the whole concept of the game. There are a few annoying things though. First of all, the ads. I get that you guys need money, and it isnt a big issue, but they are a bit intrusive. I did purchase Mr borgles to get rid of the ads though. Another issue is the general cash grabby-ness. Other than that, its an amazing game! Would definitely recommend!",
#       "user_app_rating": "4",
#       "user__comment_likes": "203",
#       "user_comment_published_at": "2020-08-13 00:33:57",
#       "user_comment_id": "gp:AOqpTOGysQfFdmw2CGX_VoAlae1xtlEvJah6jXACxVgnlxNySRuxuU8A6fYYrvUbZuHFv1-VcnWZA2hMqf0mWdY"
#     },
#     {
#       "user_name": "Eyan Mehlhoff",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgEZ4YOxZ2mzGS3wMABT6I6-v9KuO1DdoeyXWkDZA",
#       "comment": "The game itself is fantastic, great time passer. BUT Im sick and tired of the unskipaple ads that appear after every round and make new waste 30 seconds of looking it something Im not interested in, also some ads arent even skippable they just loop until you click the ad or exit the game completely. And something to improve this is get new ads and put a 5-10 timer to skip them.",
#       "user_app_rating": "2",
#       "user__comment_likes": "21",
#       "user_comment_published_at": "2019-01-06 18:41:12",
#       "user_comment_id": "gp:AOqpTOFlU9O1-fo77FvXXnuqORQRMNozGdDZXS_QlPfbp7XObVhOP_av7lTRFa7rZ_-hNOXHrJ49x0nttKyxdmk"
#     },
#     {
#       "user_name": "Gamer1Pro",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GhutQ3imCJIAbyNsvwZiZtXENqj-zZnO7BuUxgJtg",
#       "comment": "This game was such a large part of when I was sable to play on a tablet or smartphone during my childhood. Enough being nostalgic though. I try many apps out and dont usually leave reviews. But I encountered a bug in the Back to the Future event. I contacted the support team and they got back to me in just a few hours, and the bug was fixed very swiftly. I wanted to write this review as a thank you I guess, as now I can play the game without the bug.",
#       "user_app_rating": "5",
#       "user__comment_likes": "1",
#       "user_comment_published_at": "2019-01-14 19:07:18",
#       "user_comment_id": "gp:AOqpTOFQHLfTRj8jfErLJmRkPY0ioBJKwL18si4LJRC9_6bF4pE8Ol7oDtsPDkpv1mOCfqFhJhMoLlmkvd2PwIc"
#     },
#     {
#       "user_name": "iAmLegendanny",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14Gg1RWRb4UfRJxWjnszOhZoo6_LGSFPwk8h79gYoVg",
#       "comment": "Best game Ive ever played on phone. Ive been a long-term player for this game ever since it came out. Its great to pass the time. Purchasing the cheap double coins add-on makes it much more convenient and quicker to buy skins, jetpacks, and upgrades; a great investment! And with all the updates the game comes out with from spooky Halloween to jolly Christmas themes, its endless fun and entertainment. I recommend everyone to try this game and see for yourselves!",
#       "user_app_rating": "5",
#       "user__comment_likes": "348",
#       "user_comment_published_at": "2020-03-01 08:52:30",
#       "user_comment_id": "gp:AOqpTOGKpbAZnhJh75lvaQjIZW8tsOW_jxBVz0iYCdgsUU1K77fl2GPyM_xRxQPOADMG9_Upcj3iIMJ4WLisz4k"
#     },
#     {
#       "user_name": "Collin Bromeland",
#       "user_avatar": "https://play-lh.googleusercontent.com/a-/AOh14GgDmdKWuf_2GGvHLsU2fbNEQ5ZwPQ-xJsPT4WuQ",
#       "comment": "I really enjoyed this game and have been playing for years, however I wish this game had a larger \\wing\\ jetpack selection. This game also forces you to complete the entire tutorial, instead of giving you the choice to sign in, whenever you open the game on another device. I find this annoying, because whenever I try to download this on a separate device, it forces me to first complete the tutorial first.",
#       "user_app_rating": "4",
#       "user__comment_likes": "0",
#       "user_comment_published_at": "2020-03-20 04:58:18",
#       "user_comment_id": "gp:AOqpTOHRqSoQwNS9Ak1WF6NvHwYBqzFLsEH1xTHPu44iEKUPZOLX9fSpgYWCeLIh2j70RD4M55ZFemzAuhwgP-E"
#     },
#     {
#       "user_name": "A Google user",
#       "user_avatar": "https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g",
#       "comment": "Had to uninstall because too many glitches. The game freezes when I die and it wont let me do anything else, Id be forced to close the game and twice lost the rewards from the daily SAM challenge. Sometimes when I taped the screen the jetpack wouldnt activate and found myself loosing before I could even get a headstart. Fix these issues and Ill install again, sad because this is the only game I have on my phone and enjoy playing.",
#       "user_app_rating": "3",
#       "user__comment_likes": "1",
#       "user_comment_published_at": "2020-02-06 19:12:19",
#       "user_comment_id": "gp:AOqpTOGCm6p8UBwhOPrd1hRnmwVR91TZaWnzewlID88ieZ0hs9S46nDwg1jDxWybk18BIOZXy0CgUilauv6FiU8"
#     }
#   ]
# }
