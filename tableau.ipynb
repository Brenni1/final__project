# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp
import datetime as dt

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
tableau = pd.read_csv('./merge.csv')
tableau
# Out:
#          Unnamed: 0  user_pseudo_id  target_max_day_played  mission_id  \
# 0             78868             794                      0         115
# 1             78868             794                      0         113
# 2             78868             794                      0         109
# 3             78868             794                      0          11
# 4             78868             794                      0         114
# ...             ...             ...                    ...         ...
# 2680035      129581        99999617                      2         115
# 2680036      129581        99999617                      2           6
# 2680037      129581        99999617                      2          19
# 2680038      129581        99999617                      2          12
# 2680039      129581        99999617                      2          86
#
#          mission_difficulty  mission_stars_collected  day_auto_increment  \
# ...

# %%
tableau.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
tableau
# Out:
#          user_pseudo_id  target_max_day_played  mission_id  \
# 0                   794                      0         115
# 1                   794                      0         113
# 2                   794                      0         109
# 3                   794                      0          11
# 4                   794                      0         114
# ...                 ...                    ...         ...
# 2680035        99999617                      2         115
# 2680036        99999617                      2           6
# 2680037        99999617                      2          19
# 2680038        99999617                      2          12
# 2680039        99999617                      2          86
#
#          mission_difficulty  mission_stars_collected  day_auto_increment  \
# 0                       1.0                      3.0                 0.0
# 1                       1.0                      3.0                 0.0
# ...

# %%
tableau = tableau[tableau.days_played_in_month <10] # dropping values where there is effectivey less than 50 users in the dataset

# %%
tableau = tableau[tableau.lifetime_played_runs <50] # dropping values where there is effectivey less than 50 users in the dataset

# %%
tableau = tableau[tableau.mission_stars_collected <18] # dropping values where there is effectivey less than 50 users in the dataset

# %%
tableau = tableau[tableau.day_auto_increment <14] # dropping values where there is effectivey less than 50 users in the dataset

# %%
tableau = tableau[tableau.mission_id.isin([3,6,10,11,12,19,66,86,94,109,113,114,115])]

# %%
tableau
# Out:
#          user_pseudo_id  target_max_day_played  mission_id  \
# 0                   794                      0         115
# 1                   794                      0         113
# 2                   794                      0         109
# 3                   794                      0          11
# 4                   794                      0         114
# ...                 ...                    ...         ...
# 2680035        99999617                      2         115
# 2680036        99999617                      2           6
# 2680037        99999617                      2          19
# 2680038        99999617                      2          12
# 2680039        99999617                      2          86
#
#          mission_difficulty  mission_stars_collected  day_auto_increment  \
# 0                       1.0                      3.0                 0.0
# 1                       1.0                      3.0                 0.0
# ...

# %%
tableau = tableau[tableau.total_ads_watched <38]

# %%
tableau
# Out:
#          user_pseudo_id  target_max_day_played  mission_id  \
# 0                   794                      0         115
# 1                   794                      0         113
# 2                   794                      0         109
# 3                   794                      0          11
# 4                   794                      0         114
# ...                 ...                    ...         ...
# 2680035        99999617                      2         115
# 2680036        99999617                      2           6
# 2680037        99999617                      2          19
# 2680038        99999617                      2          12
# 2680039        99999617                      2          86
#
#          mission_difficulty  mission_stars_collected  day_auto_increment  \
# 0                       1.0                      3.0                 0.0
# 1                       1.0                      3.0                 0.0
# ...

# %%
tableau = tableau[tableau.target_max_day_played <24]

# %%
tableau
# Out:
#          user_pseudo_id  target_max_day_played  mission_id  \
# 0                   794                      0         115
# 1                   794                      0         113
# 2                   794                      0         109
# 3                   794                      0          11
# 4                   794                      0         114
# ...                 ...                    ...         ...
# 2680035        99999617                      2         115
# 2680036        99999617                      2           6
# 2680037        99999617                      2          19
# 2680038        99999617                      2          12
# 2680039        99999617                      2          86
#
#          mission_difficulty  mission_stars_collected  day_auto_increment  \
# 0                       1.0                      3.0                 0.0
# 1                       1.0                      3.0                 0.0
# ...

# %%
tableau.to_csv('tableau.csv')
